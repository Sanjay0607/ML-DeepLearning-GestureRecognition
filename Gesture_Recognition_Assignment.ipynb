# %% [markdown]
# # Gesture Recognition

# %% [markdown]
# Problem Statement
#
# Imagine you are working as a data scientist at a home electronics company which manufactures state of the art smart televisions. You want to develop a cool feature in the smart-TV that can recognise five different gestures performed by the user which will help users control the TV without using a remote.
#
# In this group project, you are going to build a 3D Conv model that will be able to predict the 5 gestures correctly.
#
# Each gesture corresponds to a specific command:
#
# Gesture	Corresponding Action
#
# Thumbs Up| Increase the volume.
#
# Thumbs Down| Decrease the volume.
#
# Left Swipe| 'Jump' backwards 10 seconds.
#
# Right Swipe| 'Jump' forward 10 seconds.
#
# Stop| Pause the movie.

# %% [markdown]
# # Objectives

# %% [markdown]
# Generator: The generator should be able to take a batch of videos as input without any error. Steps like cropping, resizing and normalization should be performed successfully.
#
# Model: Develop a model that is able to train without any errors which will be judged on the total number of parameters (as the inference(prediction) time should be less) and the accuracy achieved. As suggested by Snehansu, start training on a small amount of data and then proceed further.
#
# Write up: This should contain the detailed procedure followed in choosing the final model. The write up should start with the reason for choosing the base model, then highlight the reasons and metrics taken into consideration to modify and experiment to arrive at the final model.

# %%
import numpy as np
import os
from skimage.transform import resize
# from scipy.misc import imresize
from imageio import imread
import datetime
import os
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
from skimage.transform import resize

# %% [markdown]
# We set the random seed so that the results don't vary drastically.

# %%
np.random.seed(30)
import random as rn
rn.seed(30)
from keras import backend as K
import tensorflow as tf
tf.random.set_seed(30)

# %%
device_name = tf.test.gpu_device_name()
if "GPU" not in device_name:
    print("GPU device not found")
else:
    print('Found GPU at: {}'.format(device_name))
# Out:
# GPU device not found

# %% [markdown]
# - read the folder names for training and validation.
# - set the batch_size here.

# %%
train_doc = np.random.permutation(open(r'D:\Project_data\train.csv').readlines())
val_doc = np.random.permutation(open(r'D:\Project_data\val.csv').readlines())
batch_size = 64

# %%
# !nvidia-smi
# Out:
# Mon Jul 25 15:04:45 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 512.78       Driver Version: 512.78       CUDA Version: 11.6     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name            TCC/WDDM | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ... WDDM  | 00000000:06:00.0 Off |                  N/A |
# | N/A   46C    P8    N/A /  N/A |      0MiB /  2048MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A     20120      C   ...s\HP\anaconda3\python.exe    N/A      |
# +-----------------------------------------------------------------------------+

# %% [markdown]
# # Generator

# %% [markdown]
# This is one of the most important part of the code. The overall structure of the generator has been given.
# In the generator, you are going to preprocess the images as you have images of 2 different dimensions as well as create a batch of video frames.
# You have to experiment with img_idx, y,z and normalization such that you get high accuracy.

# %%
def cropResize(image, y, z):
    h, w = image.shape
    
    # if smaller image crop at center for 120x120
    if w == 160:
        image = image[:120, 20:140]

    # resize every image
    return resize(image, (y,z))

# %%
def normalizeImage(image):
    # applying normalization
    return image/255.0

# %%
pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in c:\users\hp\anaconda3\lib\site-packages (4.6.0.66)
# Requirement already satisfied: numpy>=1.14.5 in c:\users\hp\anaconda3\lib\site-packages (from opencv-python) (1.21.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
import cv2

def preprocessImage(image, y, z):
    return normalizeImage(cropResize(image, y, z))

# %%
def make3dFilter(x):
    return tuple([x]*3)

def make2dFilter(x):
    return tuple([x]*2)

# %%
def getBatchData(source_path, t, batch, batch_size, img_tensor,augment=False):
    [x,y,z] = [len(img_tensor[0]),img_tensor[1], img_tensor[2]]
    img_idx = img_tensor[0]
    batch_data = np.zeros((batch_size,x,y,z,3)) # x is the number of images you use for each video, (y,z) is the final size of the input images and 3 is the number of channels RGB
    batch_labels = np.zeros((batch_size,5)) # batch_labels is the one hot representation of the output
    
    if (augment): batch_data_aug = np.zeros((batch_size,x,y,z,3))
    
    for folder in range(batch_size): # iterate over the batch_size
        imgs = os.listdir(source_path+'/'+ t[folder + (batch*batch_size)].split(';')[0]) # read all the images in the folder
        for idx,item in enumerate(img_idx): #  Iterate iver the frames/images of a folder to read them in
            image = imread(source_path+'/'+ t[folder + (batch*batch_size)].strip().split(';')[0]+'/'+imgs[item]).astype(np.float32)

            #crop the images and resize them. Note that the images are of 2 different shape 
            #and the conv3D will throw error if the inputs in a batch have different shapes

            # separate preprocessImage function is defined for cropping, resizing and normalizing images
            batch_data[folder,idx,:,:,0] = preprocessImage(image[:, :, 0], y, z)
            batch_data[folder,idx,:,:,1] = preprocessImage(image[:, :, 1], y, z)
            batch_data[folder,idx,:,:,2] = preprocessImage(image[:, :, 2], y, z)
            if (augment):
                shifted = cv2.warpAffine(image, 
                                     np.float32([[1, 0, np.random.randint(-30,30)],[0, 1, np.random.randint(-30,30)]]),                                         (image.shape[1], image.shape[0]))
                    
                gray = cv2.cvtColor(shifted,cv2.COLOR_BGR2GRAY)

                x0, y0 = np.argwhere(gray > 0).min(axis=0)
                x1, y1 = np.argwhere(gray > 0).max(axis=0) 
                # cropping the images to have the targeted gestures and remove the noise from the images.
                cropped=shifted[x0:x1,y0:y1,:]
                image_resized=imresize(cropped,(y,z,3))
                    
                #shifted = cv2.warpAffine(image_resized, 
                #np.float32([[1, 0, np.random.randint(-3,3)],[0, 1, np.random.randint(-3,3)]]), 
                #(image_resized.shape[1], image_resized.shape[0]))
            
                batch_data_aug[folder,idx,:,:,0] = (image_resized[:,:,0])/255
                batch_data_aug[folder,idx,:,:,1] = (image_resized[:,:,1])/255
                batch_data_aug[folder,idx,:,:,2] = (image_resized[:,:,2])/255

        batch_labels[folder, int(t[folder + (batch*batch_size)].strip().split(';')[2])] = 1
        
        if (augment):
            batch_data=np.concatenate([batch_data,batch_data_aug])
            batch_labels=np.concatenate([batch_labels,batch_labels])
    return batch_data, batch_labels

# %%
def generator(source_path, folder_list, batch_size, img_tensor):
    print( 'Source path = ', source_path, '; batch size =', batch_size)
    while True:
        t = np.random.permutation(folder_list)
        num_batches = int(len(folder_list)/batch_size)
        for batch in range(num_batches): # we iterate over the number of batches
            yield getBatchData(source_path, t, batch, batch_size, img_tensor)
        
        # write the code for the remaining data points which are left after full batches
        # checking if any remaining batches are there or not
        if len(folder_list)%batch_size != 0:
            # updated the batch size and yield
            batch_size = len(folder_list)%batch_size
            yield getBatchData(source_path, t, batch, batch_size, img_tensor)

# %% [markdown]
# Note here that a video is represented above in the generator as (number of images, height, width, number of channels). Take this into consideration while creating the model architecture.

# %%
import datetime

# %%
curr_dt_time = datetime.datetime.now()
train_path = r'D:\Project_data\train'
val_path = r'D:\Project_data\val'
num_train_sequences = len(train_doc)
print('# training sequences =', num_train_sequences)
num_val_sequences = len(val_doc)
print('# validation sequences =', num_val_sequences)
num_epochs = 10
print ('# epochs =', num_epochs)
# Out:
# # training sequences = 663
# # validation sequences = 100
# # epochs = 10

# %%
def getImgTensor(n_frames):
    img_idx = np.round(np.linspace(0, 29, n_frames)).astype(int)
    return [img_idx, 100, 100, 3]

# define image tensor size
img_tensor = getImgTensor(20)
print ('# img_tensor =', img_tensor)
# Out:
# # img_tensor = [array([ 0,  2,  3,  5,  6,  8,  9, 11, 12, 14, 15, 17, 18, 20, 21, 23, 24,
#        26, 27, 29]), 100, 100, 3]

# %% [markdown]
# # Generator Validation

# %%
# check complete batch shape
sample_generator = generator(train_path, train_doc, 20, img_tensor)
sample_batch_data, sample_batch_labels = next(sample_generator)
print(sample_batch_data.shape)

# validation batch sample
sample_val_generator = generator(val_path, val_doc, 20, img_tensor)
sample_val_batch_data, sample_val_batch_labels = next(sample_val_generator)
print(sample_val_batch_data.shape)
# Out:
# Source path =  D:\Project_data\train ; batch size = 20
# (20, 20, 100, 100, 3)
# Source path =  D:\Project_data\val ; batch size = 20
# (20, 20, 100, 100, 3)

# %%
# plot generated sample images
fig, ax = plt.subplots(1,2)
ax[0].imshow(sample_val_batch_data[16,10,:,:,:])   
ax[1].imshow(sample_val_batch_data[2,10,:,:,:])
plt.show()

# %%
def plotModelHistory(h):
    fig, ax = plt.subplots(1, 2, figsize=(15,4))
    ax[0].set_ylabel('Loss')
    ax[0].set_xlabel('No. of Epochs')
    ax[0].plot(h.history['loss'])   
    ax[0].plot(h.history['val_loss'])
    ax[0].legend(['loss','val_loss'])
    ax[0].title.set_text("Train loss vs Validation loss")

    ax[1].set_ylabel('Accuracy')
    ax[1].set_xlabel('No. of Epochs')
    ax[1].plot(h.history['categorical_accuracy'])   
    ax[1].plot(h.history['val_categorical_accuracy'])
    ax[1].legend(['categorical_accuracy','val_categorical_accuracy'])
    ax[1].title.set_text("Train accuracy vs Validation accuracy")
    plt.show()

    print("Max. Training Accuracy", max(h.history['categorical_accuracy']))
    print("Max. Validaiton Accuracy", max(h.history['val_categorical_accuracy']))

# %% [markdown]
# # Model Building
# Here you make the model using different functionalities that Keras provides. Remember to use Conv3D and MaxPooling3D and not Conv2D and Maxpooling2D for a 3D convolution model. You would want to use TimeDistributed while building a Conv2D + RNN model. Also remember that the last layer is the softmax. Design the network in such a way that the model is able to give good accuracy on the least number of parameters so that it can fit in the memory of the webcam.

# %%
from keras.models import Sequential, Model
from keras.layers import Dense, GRU, Flatten, TimeDistributed, Flatten, BatchNormalization, Activation, Dropout, LSTM
from keras.layers.convolutional import Conv3D, MaxPooling3D, Conv2D, MaxPooling2D
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from keras import optimizers

# %% [markdown]
# Base Model

# %%
#write your model here
def defineModel(img_tensor):
    inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

    model = Sequential([
        Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
        MaxPooling3D(make3dFilter(2), padding='same'),
        BatchNormalization(),

        Conv3D(32, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Conv3D(64, make3dFilter(3), activation='relu'),
        MaxPooling3D(pool_size=(1,2,2), padding='same'),
        BatchNormalization(),

        Flatten(),
        Dense(128, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(64, activation='relu'),
        BatchNormalization(),
        Dropout(0.25),

        Dense(5, activation='softmax')
    ])
    model.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
    return model

model = defineModel(img_tensor)
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d (Conv3D)             (None, 16, 96, 96, 16)    6016
#
#  max_pooling3d (MaxPooling3D  (None, 8, 48, 48, 16)    0
#  )
#
#  batch_normalization (BatchN  (None, 8, 48, 48, 16)    64
#  ormalization)
#
#  conv3d_1 (Conv3D)           (None, 6, 46, 46, 32)     13856
#
#  max_pooling3d_1 (MaxPooling  (None, 6, 23, 23, 32)    0
#  3D)
#
#  batch_normalization_1 (Batc  (None, 6, 23, 23, 32)    128
#  hNormalization)
#
#  conv3d_2 (Conv3D)           (None, 4, 21, 21, 64)     55360
#
#  max_pooling3d_2 (MaxPooling  (None, 4, 11, 11, 64)    0
#  3D)
#
#  batch_normalization_2 (Batc  (None, 4, 11, 11, 64)    256
#  hNormalization)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  batch_normalization_3 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout (Dropout)           (None, 128)               0
#
#  dense_1 (Dense)             (None, 64)                8256
#
#  batch_normalization_4 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_1 (Dropout)         (None, 64)                0
#
#  dense_2 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 4,050,085
# Trainable params: 4,049,477
# Non-trainable params: 608
# _________________________________________________________________

# %%
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

# %% [markdown]
# The steps_per_epoch and validation_steps are used by fit_generator to decide the number of next() calls it need to make.

# %%
if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1

# %% [markdown]
# Model Callbacks Setup

# %%
model_name = 'model_init' + '_' + str(curr_dt_time).replace(' ','').replace(':','_') + '/'
    
if not os.path.exists(model_name):
    os.mkdir(model_name)

filepath = model_name + 'model-{epoch:05d}-{loss:.5f}-{categorical_accuracy:.5f}-{val_loss:.5f}-{val_categorical_accuracy:.5f}.h5'

#checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', period=1)
checkpoint = ModelCheckpoint(filepath, monitor='val_loss', verbose=1, save_best_only=False, save_weights_only=False, mode='auto', save_freq=1)

LR = ReduceLROnPlateau(monitor='val_loss', factor=0.2, verbose=1, patience=4)

# callbacks_list = [checkpoint, LR]
callbacks_list = [LR]

# %% [markdown]
# Test Batch Size & Frames

# %%
def testBatchSize(batch_size, n_frames):
    img_tensor = getImgTensor(n_frames)
    print("Using frames as", img_tensor[0])
    global callbacks_list
    num_epochs = 3
    train_generator = generator(train_path, train_doc, batch_size, img_tensor)
    val_generator = generator(val_path, val_doc, batch_size, img_tensor)
    if (num_train_sequences%batch_size) == 0:
        steps_per_epoch = int(num_train_sequences/batch_size)
    else:
        steps_per_epoch = (num_train_sequences//batch_size) + 1

    if (num_val_sequences%batch_size) == 0:
        validation_steps = int(num_val_sequences/batch_size)
    else:
        validation_steps = (num_val_sequences//batch_size) + 1

    model = defineModel(img_tensor)
    model.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
                callbacks=callbacks_list, validation_data=val_generator, 
                validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)

# %% [markdown]
# With above observations, we can see that batch size is not impacting training time but number of frames. We will use batch size of 64 as it seems optimal. It is commented as it takes a lot of time to run that is restricting for the notebook to completely run

# %% [markdown]
# Model 1 - Frames-16, Epoc-20

# %%
n_frames = 16
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model1 = Sequential([
    Conv3D(16, make3dFilter(5), activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), activation='relu'),
    MaxPooling3D(pool_size=(1,2,2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d1")
model1.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model1.summary())

model1_history = model1.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_3 (Conv3D)           (None, 12, 96, 96, 16)    6016
#
#  max_pooling3d_3 (MaxPooling  (None, 6, 48, 48, 16)    0
#  3D)
#
#  batch_normalization_5 (Batc  (None, 6, 48, 48, 16)    64
#  hNormalization)
#
#  conv3d_4 (Conv3D)           (None, 4, 46, 46, 32)     13856
#
#  max_pooling3d_4 (MaxPooling  (None, 4, 23, 23, 32)    0
#  3D)
#
#  batch_normalization_6 (Batc  (None, 4, 23, 23, 32)    128
#  hNormalization)
#
#  conv3d_5 (Conv3D)           (None, 2, 21, 21, 64)     55360
#
#  max_pooling3d_5 (MaxPooling  (None, 2, 11, 11, 64)    0
#  3D)
#
#  batch_normalization_7 (Batc  (None, 2, 11, 11, 64)    256
#  hNormalization)
#
#  flatten_1 (Flatten)         (None, 15488)             0
#
#  dense_3 (Dense)             (None, 128)               1982592
#
#  batch_normalization_8 (Batc  (None, 128)              512
#  hNormalization)
#
#  dropout_2 (Dropout)         (None, 128)               0
#
#  dense_4 (Dense)             (None, 64)                8256
#
#  batch_normalization_9 (Batc  (None, 64)               256
#  hNormalization)
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_5 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 2,067,621
# Trainable params: 2,067,013
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  D:\Project_data\train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 1.5252 - categorical_accuracy: 0.4630 Source path =  D:\Project_data\val ; batch size = 64
# 11/11 [==============================] - 528s 48s/step - loss: 1.5252 - categorical_accuracy: 0.4630 - val_loss: 7.6442 - val_categorical_accuracy: 0.2400 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - 209s 19s/step - loss: 0.8346 - categorical_accuracy: 0.6759 - val_loss: 8.5034 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - 201s 18s/step - loss: 0.8690 - categorical_accuracy: 0.6601 - val_loss: 3.2987 - val_categorical_accuracy: 0.2679 - lr: 0.0010
# Epoch 4/20
# 11/11 [==============================] - 178s 16s/step - loss: 0.7757 - categorical_accuracy: 0.7339 - val_loss: 2.6831 - val_categorical_accuracy: 0.1562 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - 158s 15s/step - loss: 0.6305 - categorical_accuracy: 0.7703 - val_loss: 3.2336 - val_categorical_accuracy: 0.2812 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - 150s 14s/step - loss: 0.6733 - categorical_accuracy: 0.7512 - val_loss: 3.3718 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 7/20
# 11/11 [==============================] - 141s 13s/step - loss: 0.5887 - categorical_accuracy: 0.7931 - val_loss: 2.9332 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 8/20
# 11/11 [==============================] - 132s 12s/step - loss: 0.5900 - categorical_accuracy: 0.7754 - val_loss: 1.9653 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 9/20
# 11/11 [==============================] - 133s 12s/step - loss: 0.5202 - categorical_accuracy: 0.8128 - val_loss: 6.8613 - val_categorical_accuracy: 0.0000e+00 - lr: 0.0010
# Epoch 10/20
# 11/11 [==============================] - 131s 12s/step - loss: 0.6692 - categorical_accuracy: 0.7647 - val_loss: 4.4203 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 11/20
# 11/11 [==============================] - 132s 12s/step - loss: 0.5740 - categorical_accuracy: 0.7807 - val_loss: 2.2615 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 12/20
# 11/11 [==============================] - 132s 12s/step - loss: 0.4273 - categorical_accuracy: 0.8235 - val_loss: 1.6167 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 13/20
# 11/11 [==============================] - 131s 12s/step - loss: 0.6338 - categorical_accuracy: 0.7701 - val_loss: 2.9300 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 14/20
# 11/11 [==============================] - 568s 56s/step - loss: 0.5650 - categorical_accuracy: 0.7914 - val_loss: 1.7944 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 15/20
# 11/11 [==============================] - 58s 5s/step - loss: 0.4095 - categorical_accuracy: 0.8610 - val_loss: 1.1568 - val_categorical_accuracy: 0.5000 - lr: 0.0010
# Epoch 16/20
# 11/11 [==============================] - 81s 8s/step - loss: 0.4618 - categorical_accuracy: 0.8449 - val_loss: 1.1417 - val_categorical_accuracy: 0.7500 - lr: 0.0010
# Epoch 17/20
# 11/11 [==============================] - 131s 12s/step - loss: 0.3577 - categorical_accuracy: 0.9091 - val_loss: 0.3771 - val_categorical_accuracy: 0.8750 - lr: 0.0010
# Epoch 18/20
# 11/11 [==============================] - 132s 12s/step - loss: 0.3079 - categorical_accuracy: 0.8824 - val_loss: 1.5178 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 19/20
# 11/11 [==============================] - 124s 11s/step - loss: 0.2147 - categorical_accuracy: 0.9198 - val_loss: 0.2829 - val_categorical_accuracy: 0.8750 - lr: 0.0010
# Epoch
 25, 25, 32)    128
#  chNormalization)
#
#  conv3d_8 (Conv3D)           (None, 8, 25, 25, 64)     55360
#
#  max_pooling3d_8 (MaxPooling  (None, 4, 13, 13, 64)    0
#  3D)
#
#  batch_normalization_12 (Bat  (None, 4, 13, 13, 64)    256
#  chNormalization)
#
#  flatten_2 (Flatten)         (None, 43264)             0
#
#  dense_6 (Dense)             (None, 128)               5537920
#
#  batch_normalization_13 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_4 (Dropout)         (None, 128)               0
#
#  dense_7 (Dense)             (None, 64)                8256
#
#  batch_normalization_14 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_5 (Dropout)         (None, 64)                0
#
#  dense_8 (Dense)             (None, 5)                 325
#
# =================================================================
# Total params: 5,618,245
# Trainable params: 5,617,637
# Non-trainable params: 608
# _________________________________________________________________
# None
# Source path =  D:\Project_data\train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 1.3426 - categorical_accuracy: 0.5264 Source path =  D:\Project_data\val ; batch size = 64
# 11/11 [==============================] - 440s 40s/step - loss: 1.3426 - categorical_accuracy: 0.5264 - val_loss: 1.9375 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - 167s 15s/step - loss: 0.6523 - categorical_accuracy: 0.7312 - val_loss: 2.2150 - val_categorical_accuracy: 0.2344 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - 273s 26s/step - loss: 0.7713 - categorical_accuracy: 0.6996 - val_loss: 1.7144 - val_categorical_accuracy: 0.3393 - lr: 0.0010
# Epoch 4/20
# 11/11 [==============================] - 352s 32s/step - loss: 0.5956 - categorical_accuracy: 0.7897 - val_loss: 2.2685 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - 317s 29s/step - loss: 0.4066 - categorical_accuracy: 0.8708 - val_loss: 2.2796 - val_categorical_accuracy: 0.3125 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - 290s 26s/step - loss: 0.4392 - categorical_accuracy: 0.8086 - val_loss: 3.2498 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 7/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4029 - categorical_accuracy: 0.8621
# Epoch 7: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 288s 26s/step - loss: 0.4029 - categorical_accuracy: 0.8621 - val_loss: 2.9096 - val_categorical_accuracy: 0.1250 - lr: 0.0010
# Epoch 8/20
# 11/11 [==============================] - 264s 24s/step - loss: 0.3526 - categorical_accuracy: 0.8930 - val_loss: 3.3864 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 9/20
# 11/11 [==============================] - 266s 24s/step - loss: 0.3527 - categorical_accuracy: 0.8824 - val_loss: 2.1254 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 10/20
# 11/11 [==============================] - 264s 24s/step - loss: 0.2895 - categorical_accuracy: 0.9037 - val_loss: 2.9760 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 11/20
# 11/11 [==============================] - ETA: 0s - loss: 0.3211 - categorical_accuracy: 0.8877
# Epoch 11: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 264s 24s/step - loss: 0.3211 - categorical_accuracy: 0.8877 - val_loss: 2.1232 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 12/20
# 11/11 [==============================] - 267s 24s/step - loss: 0.2579 - categorical_accuracy: 0.9251 - val_loss: 3.1999 - val_categorical_accuracy: 0.1250 - lr: 4.0000e-05
# Epoch 13/20
# 11/11 [==============================] - 264s 24s/step - loss: 0.2833 - categorical_accuracy: 0.8984 - val_loss: 1.9294 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 14/20
# 11/11 [==============================] - 266s 24s/step - loss: 0.2205 - categorical_accuracy: 0.9465 - val_loss: 2.6952 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 15/20
# 11/11 [==============================] - ETA: 0s - loss: 0.2166 - categorical_accuracy: 0.9465
# Epoch 15: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 11/11 [==============================] - 267s 24s/step - loss: 0.2166 - categorical_accuracy: 0.9465 - val_loss: 3.2227 - val_categorical_accuracy: 0.0000e+00 - lr: 4.0000e-05
# Epoch 16/20
# 11/11 [==============================] - 127s 10s/step - loss: 0.2256 - categorical_accuracy: 0.9305 - val_loss: 2.6361 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 17/20
# 11/11 [==============================] - 102s 9s/step - loss: 0.2350 - categorical_accuracy: 0.9358 - val_loss: 2.1796 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 18/20
# 11/11 [==============================] - 99s 9s/step - loss: 0.2477 - categorical_accuracy: 0.9305 - val_loss: 1.6154 - val_categorical_accuracy: 0.3750 - lr: 8.0000e-06
# Epoch 19/20
# 11/11 [==============================] - 100s 9s/step - loss: 0.3060 - categorical_accuracy: 0.9037 - val_loss: 3.3356 - val_categorical_accuracy: 0.1250 - lr: 8.0000e-06
# Epoch 20/20
# 11/11 [==============================] - 100s 9s/step - loss: 0.1704 - categorical_accuracy: 0.9465 - val_loss: 3.0159 - val_categorical_accuracy: 0.3750 - lr: 8.0000e-06

# %%
plotModelHistory(model3_history)
# Out:
# Max. Training Accuracy 0.9465240836143494
# Max. Validaiton Accuracy 0.375

# %% [markdown]
# Model 4: Frames-20, Same pooling in Conv3D layer

# %%
n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model4 = Sequential([
    Conv3D(16, make3dFilter(3), padding='same', activation='relu', input_shape=inputShape),
    MaxPooling3D(make3dFilter(2), padding='same'),
    BatchNormalization(),

    Conv3D(32, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(64, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Conv3D(128, make3dFilter(3), padding='same', activation='relu'),
    MaxPooling3D(pool_size=(2), padding='same'),
    BatchNormalization(),

    Flatten(),
    Dense(128, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(64, activation='relu'),
    BatchNormalization(),
    Dropout(0.25),

    Dense(5, activation='softmax')
], name="conv_3d4")
model4.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model4.summary())

model4_history = model4.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_9 (Conv3D)           (None, 20, 100, 100, 16)  1312
#
#  max_pooling3d_9 (MaxPooling  (None, 10, 50, 50, 16)   0
#  3D)
#
#  batch_normalization_15 (Bat  (None, 10, 50, 50, 16)   64
#  chNormalization)
#
#  conv3d_10 (Conv3D)          (None, 10, 50, 50, 32)    13856
#
#  max_pooling3d_10 (MaxPoolin  (None, 5, 25, 25, 32)    0
#  g3D)
#
#  batch_normalization_16 (Bat  (None, 5, 25, 25, 32)    128
#  chNormalization)
#
#  conv3d_11 (Conv3D)          (None, 5, 25, 25, 64)     55360
#
#  max_pooling3d_11 (MaxPoolin  (None, 3, 13, 13, 64)    0
#  g3D)
#
#  batch_normalization_17 (Bat  (None, 3, 13, 13, 64)    256
#  chNormalization)
#
#  conv3d_12 (Conv3D)          (None, 3, 13, 13, 128)    221312
#
#  max_pooling3d_12 (MaxPoolin  (None, 2, 7, 7, 128)     0
#  g3D)
#
#  batch_normalization_18 (Bat  (None, 2, 7, 7, 128)     512
#  chNormalization)
#
#  flatten_3 (Flatten)         (None, 12544)             0
#
#  dense_9 (Dense)             (None, 128)               1605760
#
#  batch_normalization_19 (Bat  (None, 128)              512
#  chNormalization)
#
#  dropout_6 (Dropout)         (None, 128)               0
#
#  dense_10 (Dense)            (None, 64)                8256
#
#  batch_normalization_20 (Bat  (None, 64)               256
#  chNormalization)
#
#  dropout_7 (Dropout)         (None, 64)                0
#
#  dense_11 (Dense)            (None, 5)                 325
#
# =================================================================
# Total params: 1,907,909
# Trainable params: 1,907,045
# Non-trainable params: 864
# _________________________________________________________________
# None
# Source path =  D:\Project_data\train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 1.4178 - categorical_accuracy: 0.4827 Source path =  D:\Project_data\val ; batch size = 64
# 11/11 [==============================] - 295s 27s/step - loss: 1.4178 - categorical_accuracy: 0.4827 - val_loss: 1.5376 - val_categorical_accuracy: 0.2600 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - 113s 10s/step - loss: 0.8568 - categorical_accuracy: 0.7036 - val_loss: 1.5304 - val_categorical_accuracy: 0.3438 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - 109s 10s/step - loss: 0.7544 - categorical_accuracy: 0.7233 - val_loss: 1.6510 - val_categorical_accuracy: 0.4464 - lr: 0.0010
# Epoch 4/20
# 11/11 [==============================] - 96s 9s/step - loss: 0.5359 - categorical_accuracy: 0.8069 - val_loss: 1.8606 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - 84s 8s/step - loss: 0.6410 - categorical_accuracy: 0.7703 - val_loss: 1.8342 - val_categorical_accuracy: 0.3125 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - ETA: 0s - loss: 0.5913 - categorical_accuracy: 0.7751
# Epoch 6: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 79s 7s/step - loss: 0.5913 - categorical_accuracy: 0.7751 - val_loss: 2.5918 - val_categorical_accuracy: 0.3750 - lr: 0.0010
# Epoch 7/20
# 11/11 [==============================] - 76s 7s/step - loss: 0.5974 - categorical_accuracy: 0.7734 - val_loss: 3.0102 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 8/20
# 11/11 [==============================] - 70s 6s/step - loss: 0.5136 - categorical_accuracy: 0.8289 - val_loss: 1.7120 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 9/20
# 11/11 [==============================] - 70s 6s/step - loss: 0.3239 - categorical_accuracy: 0.8770 - val_loss: 2.2900 - val_categorical_accuracy: 0.3750 - lr: 2.0000e-04
# Epoch 10/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4409 - categorical_accuracy: 0.8342
# Epoch 10: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 70s 6s/step - loss: 0.4409 - categorical_accuracy: 0.8342 - val_loss: 2.5756 - val_categorical_accuracy: 0.0000e+00 - lr: 2.0000e-04
# Epoch 11/20
# 11/11 [==============================] - 70s 6s/step - loss: 0.2819 - categorical_accuracy: 0.8984 - val_loss: 1.8668 - val_categorical_accuracy: 0.2500 - lr: 4.0000e-05
# Epoch 12/20
# 11/11 [==============================] - 68s 6s/step - loss: 0.2419 - categorical_accuracy: 0.9251 - val_loss: 1.5858 - val_categorical_accuracy: 0.5000 - lr: 4.0000e-05
# Epoch 13/20
# 11/11 [==============================] - 69s 6s/step - loss: 0.2736 - categorical_accuracy: 0.9037 - val_loss: 1.6639 - val_categorical_accuracy: 0.1250 - lr: 4.0000e-05
# Epoch 14/20
# 11/11 [==============================] - ETA: 0s - loss: 0.2582 - categorical_accuracy: 0.9091
# Epoch 14: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 11/11 [==============================] - 69s 6s/step - loss: 0.2582 - categorical_accuracy: 0.9091 - val_loss: 1.7401 - val_categorical_accuracy: 0.3750 - lr: 4.0000e-05
# Epoch 15/20
# 11/11 [==============================] - 69s 6s/step - loss: 0.2384 - categorical_accuracy: 0.9358 - val_loss: 2.3154 - val_categorical_accuracy: 0.1250 - lr: 8.0000e-06
# Epoch 16/20
# 11/11 [==============================] - 70s 6s/step - loss: 0.3305 - categorical_accuracy: 0.8610 - val_loss: 1.7167 - val_categorical_accuracy: 0.3750 - lr: 8.0000e-06
# Epoch 17/20
# 11/11 [==============================] - 69s 6s/step - loss: 0.2462 - categorical_accuracy: 0.9144 - val_loss: 1.3931 - val_categorical_accuracy: 0.5000 - lr: 8.0000e-06
# Epoch 18/20
# 11/11 [==============================] - 69s 6s/step - loss: 0.2493 - categorical_accuracy: 0.9037 - val_loss: 1.6126 - val_categorical_accuracy: 0.5000 - lr: 8.0000e-06
# Epoch 19/20
# 11/11 [==============================] - 67s 6s/step - loss: 0.2964 - categorical_accuracy: 0.8877 - val_loss: 1.9154 - val_categorical_accuracy: 0.1250 - lr: 8.0000e-06
# Epoch 20/20
# 11/11 [==============================] - 68s 6s/step - loss: 0.1787 - categorical_accuracy: 0.9679 - val_loss: 1.4574 - val_categorical_accuracy: 0.3750 - lr: 8.0000e-06

# %%
plotModelHistory(model4_history)
# Out:
# Max. Training Accuracy 0.9679144620895386
# Max. Validaiton Accuracy 0.5

# %% [markdown]
# Model 5: Frames:20, Epocs-20, BS-64, reduced kernel to (2,2,2), switching BatchNormalization before MaxPooling.

# %%
n_frames = 20
num_epochs = 20
batch_size = 64

img_tensor = getImgTensor(n_frames)
train_generator = generator(train_path, train_doc, batch_size, img_tensor)
val_generator = generator(val_path, val_doc, batch_size, img_tensor)

if (num_train_sequences%batch_size) == 0:
    steps_per_epoch = int(num_train_sequences/batch_size)
else:
    steps_per_epoch = (num_train_sequences//batch_size) + 1

if (num_val_sequences%batch_size) == 0:
    validation_steps = int(num_val_sequences/batch_size)
else:
    validation_steps = (num_val_sequences//batch_size) + 1
    
inputShape = (len(img_tensor[0]), img_tensor[1], img_tensor[2], img_tensor[3])

model5 = Sequential([
    Conv3D(16, make3dFilter(2), padding='same', activation='relu', input_shape=inputShape),
    BatchNormalization(),
    MaxPooling3D(make3dFilter(2)),

    Conv3D(32, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(64, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Conv3D(128, make3dFilter(2), padding='same', activation='relu'),
    BatchNormalization(),
    MaxPooling3D(pool_size=(2)),

    Flatten(),
    Dense(256, activation='relu'),
    # BatchNormalization(),
    # Dropout(0.3),

    Dense(128, activation='relu'),
    # BatchNormalization(),
    # Dropout(0.2),

    Dense(5, activation='softmax')
], name="conv_3d5")
model5.compile(optimizer=optimizers.Adam(), loss='categorical_crossentropy', metrics=['categorical_accuracy'])
print(model5.summary())

model5_history = model5.fit_generator(train_generator, steps_per_epoch=steps_per_epoch, epochs=num_epochs, verbose=1, 
            callbacks=callbacks_list, validation_data=val_generator, 
            validation_steps=validation_steps, class_weight=None, workers=1, initial_epoch=0)
# Out:
# Model: "conv_3d5"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  conv3d_13 (Conv3D)          (None, 20, 100, 100, 16)  400
#
#  batch_normalization_21 (Bat  (None, 20, 100, 100, 16)  64
#  chNormalization)
#
#  max_pooling3d_13 (MaxPoolin  (None, 10, 50, 50, 16)   0
#  g3D)
#
#  conv3d_14 (Conv3D)          (None, 10, 50, 50, 32)    4128
#
#  batch_normalization_22 (Bat  (None, 10, 50, 50, 32)   128
#  chNormalization)
#
#  max_pooling3d_14 (MaxPoolin  (None, 5, 25, 25, 32)    0
#  g3D)
#
#  conv3d_15 (Conv3D)          (None, 5, 25, 25, 64)     16448
#
#  batch_normalization_23 (Bat  (None, 5, 25, 25, 64)    256
#  chNormalization)
#
#  max_pooling3d_15 (MaxPoolin  (None, 2, 12, 12, 64)    0
#  g3D)
#
#  conv3d_16 (Conv3D)          (None, 2, 12, 12, 128)    65664
#
#  batch_normalization_24 (Bat  (None, 2, 12, 12, 128)   512
#  chNormalization)
#
#  max_pooling3d_16 (MaxPoolin  (None, 1, 6, 6, 128)     0
#  g3D)
#
#  flatten_4 (Flatten)         (None, 4608)              0
#
#  dense_12 (Dense)            (None, 256)               1179904
#
#  dense_13 (Dense)            (None, 128)               32896
#
#  dense_14 (Dense)            (None, 5)                 645
#
# =================================================================
# Total params: 1,301,045
# Trainable params: 1,300,565
# Non-trainable params: 480
# _________________________________________________________________
# None
# Source path =  D:\Project_data\train ; batch size = 64
# Epoch 1/20
# 11/11 [==============================] - ETA: 0s - loss: 4.6391 - categorical_accuracy: 0.3695 Source path =  D:\Project_data\val ; batch size = 64
# 11/11 [==============================] - 239s 22s/step - loss: 4.6391 - categorical_accuracy: 0.3695 - val_loss: 1.4995 - val_categorical_accuracy: 0.3700 - lr: 0.0010
# Epoch 2/20
# 11/11 [==============================] - 92s 8s/step - loss: 1.0982 - categorical_accuracy: 0.5613 - val_loss: 4.5225 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 3/20
# 11/11 [==============================] - 87s 8s/step - loss: 0.9436 - categorical_accuracy: 0.6522 - val_loss: 7.5368 - val_categorical_accuracy: 0.2143 - lr: 0.0010
# Epoch 4/20
# 11/11 [==============================] - 74s 7s/step - loss: 0.6463 - categorical_accuracy: 0.7339 - val_loss: 7.9669 - val_categorical_accuracy: 0.2500 - lr: 0.0010
# Epoch 5/20
# 11/11 [==============================] - ETA: 0s - loss: 0.4115 - categorical_accuracy: 0.8373
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.00020000000949949026.
# 11/11 [==============================] - 71s 6s/step - loss: 0.4115 - categorical_accuracy: 0.8373 - val_loss: 11.9557 - val_categorical_accuracy: 0.1875 - lr: 0.0010
# Epoch 6/20
# 11/11 [==============================] - 62s 6s/step - loss: 0.3934 - categorical_accuracy: 0.8421 - val_loss: 12.3857 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 7/20
# 11/11 [==============================] - 59s 5s/step - loss: 0.3039 - categorical_accuracy: 0.8571 - val_loss: 17.8467 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 8/20
# 11/11 [==============================] - 55s 5s/step - loss: 0.2160 - categorical_accuracy: 0.9251 - val_loss: 12.4189 - val_categorical_accuracy: 0.1250 - lr: 2.0000e-04
# Epoch 9/20
# 11/11 [==============================] - ETA: 0s - loss: 0.1267 - categorical_accuracy: 0.9412
# Epoch 9: ReduceLROnPlateau reducing learning rate to 4.0000001899898055e-05.
# 11/11 [==============================] - 58s 5s/step - loss: 0.1267 - categorical_accuracy: 0.9412 - val_loss: 14.2029 - val_categorical_accuracy: 0.2500 - lr: 2.0000e-04
# Epoch 10/20
# 11/11 [==============================] - 52s 5s/step - loss: 0.2349 - categorical_accuracy: 0.9091 - val_loss: 18.9584 - val_categorical_accuracy: 0.0000e+00 - lr: 4.0000e-05
# Epoch 11/20
# 11/11 [==============================] - 54s 5s/step - loss: 0.1626 - categorical_accuracy: 0.9412 - val_loss: 25.4357 - val_categorical_accuracy: 0.1250 - lr: 4.0000e-05
# Epoch 12/20
# 11/11 [==============================] - 54s 5s/step - loss: 0.1296 - categorical_accuracy: 0.9572 - val_loss: 19.0270 - val_categorical_accuracy: 0.1250 - lr: 4.0000e-05
# Epoch 13/20
# 11/11 [==============================] - ETA: 0s - loss: 0.1227 - categorical_accuracy: 0.9626
# Epoch 13: ReduceLROnPlateau reducing learning rate to 8.000000525498762e-06.
# 11/11 [==============================] - 54s 5s/step - loss: 0.1227 - categorical_accuracy: 0.9626 - val_loss: 15.5112 - val_categorical_accuracy: 0.3750 - lr: 4.0000e-05
# Epoch 14/20
# 11/11 [==============================] - 53s 5s/step - loss: 0.1740 - categorical_accuracy: 0.9626 - val_loss: 17.9788 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 15/20
# 11/11 [==============================] - 54s 5s/step - loss: 0.1882 - categorical_accuracy: 0.9412 - val_loss: 8.9830 - val_categorical_accuracy: 0.1250 - lr: 8.0000e-06
# Epoch 16/20
# 11/11 [==============================] - 53s 5s/step - loss: 0.1341 - categorical_accuracy: 0.9733 - val_loss: 11.6611 - val_categorical_accuracy: 0.3750 - lr: 8.0000e-06
# Epoch 17/20
# 11/11 [==============================] - ETA: 0s - loss: 0.1212 - categorical_accuracy: 0.9733
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.6000001778593287e-06.
# 11/11 [==============================] - 53s 5s/step - loss: 0.1212 - categorical_accuracy: 0.9733 - val_loss: 13.9457 - val_categorical_accuracy: 0.2500 - lr: 8.0000e-06
# Epoch 18/20
# 11/11 [==============================] - 54s 5s/step - loss: 0.1440 - categorical_accuracy: 0.9572 - val_loss: 16.9848 - val_categorical_accuracy: 0.3750 - lr: 1.6000e-06
# Epoch 19/20
# 11/11 [==============================] - 53s 5s/step - loss: 0.1586 - categorical_accuracy: 0.9412 - val_loss: 27.7771 - val_categorical_accuracy: 0.0000e+00 - lr: 1.6000e-06
# Epoch 20/20
# 11/11 [==============================] - 54s 5s/step - loss: 0.1236 - categorical_accuracy: 0.9733 - val_loss: 19.5179 - val_categorical_accuracy: 0.2500 - lr: 1.6000e-